# %% [markdown]
# # 18th Assignment - Forecasting - Airlines + Data

# %%
import pandas as pd

# %%
data = pd.read_excel("C:/Users/Narsing/Downloads/Assigments data science/18th-Assignmnet-Forecasting-main/Airlines+Data.xlsx")
data
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306
#
# [96 rows x 2 columns]

# %%
data.head()
# Out:
#        Month  Passengers
# 0 1995-01-01         112
# 1 1995-02-01         118
# 2 1995-03-01         132
# 3 1995-04-01         129
# 4 1995-05-01         121

# %%
data.shape
# Out:
# (96, 2)

# %%
data.dtypes
# Out:
# Month         datetime64[ns]
# Passengers             int64
# dtype: object

# %%
data.isna().sum()
# Out:
# Month         0
# Passengers    0
# dtype: int64

# %%
data.set_index('Month', inplace=True)
data.head()
# Out:
#             Passengers
# Month
# 1995-01-01         112
# 1995-02-01         118
# 1995-03-01         132
# 1995-04-01         129
# 1995-05-01         121

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Visualizing the overall data in order to the components present in our data
plt.title("Line Plot", size = 15, weight = 'bold')
plt.ylabel("Passengers", size = 10, weight = 'bold')
plt.plot(data['Passengers'])

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Passengers'}>]], dtype=object)

# %%
from matplotlib import pyplot
import numpy as np

# %%
data.plot(kind = 'kde')
plt.title("Density Plot",size = 15, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Density Plot')

# %%
from pandas.plotting import lag_plot

lag_plot(data['Passengers'])
ax = plt.axes()
plt.show()

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(data.Passengers,lags=12)
ax = plt.axes()
ax.set_facecolor("white")
tsa_plots.plot_pacf(data.Passengers,lags=12)
ax = plt.axes()
ax.set_facecolor("black")
plt.show()
# Out:
# C:\Users\Narsing\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
data["t"] = np.arange(1,97)
data["t_squared"] = data["t"]*data["t"]

data["log_psngr"] = np.log(data["Passengers"])

data.head()
# Out:
#             Passengers  t  t_squared  log_psngr
# Month
# 1995-01-01         112  1          1   4.718499
# 1995-02-01         118  2          4   4.770685
# 1995-03-01         132  3          9   4.882802
# 1995-04-01         129  4         16   4.859812
# 1995-05-01         121  5         25   4.795791

# %%
Train = data.head(84)
Test = data.tail(12)

# %%
import statsmodels.formula.api as smf
import numpy as np
def RMSE(y_true, y_pred):
    return np.sqrt(((y_true - y_pred) ** 2).mean())


linear_model = smf.ols('Passengers~t',data=Train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(Test['t'])))
rmse_linear_model = RMSE(Test['Passengers'], pred_linear)
rmse_linear_model
# Out:
# 53.199236534802715

# %%
Exp = smf.ols('log_psngr~t',data=Train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(Test['t'])))
rmse_Exp_model = RMSE(Test['Passengers'], np.exp(pred_Exp))
rmse_Exp_model
# Out:
# 46.0573611031562

# %%
Quad = smf.ols('Passengers~t+t_squared',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["t","t_squared"]]))
rmse_Quad_model = RMSE(Test['Passengers'], pred_Quad)
rmse_Quad_model
# Out:
# 48.051888979330975

# %%
Quad = smf.ols('Passengers~t+t_squared',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["t","t_squared"]]))
rmse_Quad_model = RMSE(Test['Passengers'], pred_Quad)
rmse_Quad_model
# Out:
# 48.051888979330975
